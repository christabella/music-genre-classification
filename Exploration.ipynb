# %% [markdown]
# # Exploring the data

# %% [markdown]
# Using TPOT to get good initial hyperparameters and model selection.

# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Load the data and cleanup

# Read data
train_data_df = pd.read_csv("data/train_data.csv", header=None)
test_data_df = pd.read_csv("data/test_data.csv", header=None)
train_labels_df = pd.read_csv("data/train_labels.csv", header=None)

print(train_data_df.shape)
print(test_data_df.shape)
train_data_df.head()
# Out:
# (4363, 264)
# (6544, 264)
#       0       1       2       3       4       5       6       7       8    \
# 0  1040.7  2315.6  2839.1  2552.2  2290.4  1913.8  2152.6  1930.3  2079.3
# 1  2309.4  4780.4  4055.7  3120.5  1979.9  2343.6  2634.2  3208.5  3078.0
# 2  2331.9  4607.0  4732.3  5007.0  3164.9  3171.9  2915.7  3282.3  2400.0
# 3  3350.9  6274.4  5037.0  4609.7  3438.8  3925.8  3746.4  3539.4  3053.7
# 4  2017.6  3351.8  2924.9  2726.3  1979.9  1930.9  2083.4  1889.2  1695.4
#
#       9      ...          254      255       256       257       258  \
# 0  1706.7    ...     0.216490  0.36548  0.093584  0.166870  0.083426
# 1  3374.7    ...     0.100670  0.14739  0.102560  0.213040  0.082041
# 2  1895.2    ...     0.126760  0.36321  0.114200  0.223780  0.100770
# 3  3075.4    ...     0.096479  0.28950  0.074124  0.201580  0.049032
# 4  1911.7    ...     0.138340  0.38266  0.079402  0.063495  0.053717
#
#         259       260       261       262       263
# 0  0.118090  0.089792  0.074371  0.073162  0.059463
# 1  0.080967  0.076450  0.052523  0.052357  0.055297
# 2  0.186910  0.067270  0.061138  0.085509  0.049422
# 3  0.130210  0.045800  0.080885  0.148910  0.042027
# 4  0.086750  0.062090  0.048999  0.033159  0.070813
#
# [5 rows x 264 columns]

# %%
train_data_df = train_data_df.drop([216, 217, 218, 219], axis=1)
test_data_df = test_data_df.drop([216, 217, 218, 219], axis=1)

# %%
from sklearn import preprocessing

# min_max_scaler = preprocessing.StandardScaler()
# min_max_scaler = preprocessing.RobustScaler()
min_max_scaler = preprocessing.MinMaxScaler()

train_data = min_max_scaler.fit_transform(train_data_df)

# %%
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
 
X_train, X_test, y_train, y_test = train_test_split(train_data, train_labels_df.as_matrix().ravel(),
                                                    train_size=0.75, test_size=0.25)

tpot = TPOTClassifier(generations=5, population_size=10, verbosity=2, scoring='neg_log_loss')
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
tpot.export('tpot_pipeline_neglogloss_minmaxscaled_droppedfeatures.py')
# Out:
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=60), HTML(value='')))
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: RandomForestClassifier(input_matrix, bootstrap=True, criterion=entropy, max_features=0.4, min_samples_leaf=4, min_samples_split=12, n_estimators=100)
# -1.27484218014
# True

# %%
pd.DataFrame.from_dict(tpot.evaluated_individuals_)
# Out:
#                   BernoulliNB(Binarizer(PCA(input_matrix, PCA__iterated_power=9, PCA__svd_solver=randomized), Binarizer__threshold=1.0), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           -2.49091
# mutation_count                                                     1
# operator_count                                                     3
# predecessor        (BernoulliNB(Binarizer(input_matrix, Binarizer...
#
#                   BernoulliNB(Binarizer(input_matrix, Binarizer__threshold=1.0), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           -8.79565
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   BernoulliNB(CombineDFs(input_matrix, input_matrix), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           -15.8337
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   BernoulliNB(DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=9, DecisionTreeClassifier__min_samples_split=14), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           -11.8637
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   BernoulliNB(FastICA(input_matrix, FastICA__tol=0.55), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           -2.07088
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (BernoulliNB(input_matrix, BernoulliNB__alpha=...
#
#                   BernoulliNB(GaussianNB(input_matrix), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           -12.5658
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   BernoulliNB(GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=6, GradientBoostingClassifier__max_features=0.55, GradientBoostingClassifier__min_samples_leaf=19, GradientBoostingClassifier__min_samples_split=11, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.1), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           -12.6098
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (BernoulliNB(GradientBoostingClassifier(input_...
#
#                   BernoulliNB(GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=6, GradientBoostingClassifier__max_features=0.55, GradientBoostingClassifier__min_samples_leaf=4, GradientBoostingClassifier__min_samples_split=11, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.1), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           -12.5662
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   BernoulliNB(StandardScaler(input_matrix), BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           -12.6106
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (BernoulliNB(GradientBoostingClassifier(input_...
#
#                   BernoulliNB(ZeroCount(input_matrix), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           -11.8001
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (BernoulliNB(DecisionTreeClassifier(input_matr...
#
#                                                                                                                             ...                                                                                                            \
# crossover_count                                                                                                             ...
# generation                                                                                                                  ...
# internal_cv_score                                                                                                           ...
# mutation_count                                                                                                              ...
# operator_count                                                                                                              ...
# predecessor                                                                                                                 ...
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.001, XGBClassifier__max_depth=5, XGBClassifier__min_child_weight=9, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.7)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           -2.15085
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (XGBClassifier(input_matrix, XGBClassifier__le...
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=2, XGBClassifier__min_child_weight=3, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.55)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           -1.60556
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=17, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.85)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           -1.57847
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=3, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.65)  \
# crossover_count                                                    1
# generation                                                   INVALID
# internal_cv_score                                           -1.57092
# mutation_count                                                     0
# operator_count                                                     1
# predecessor        (XGBClassifier(input_matrix, XGBClassifier__le...
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=5, XGBClassifier__min_child_weight=18, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.75)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           -1.56283
# mutation_count                                                     1
# operator_count                                                     1
# predecessor                              (GaussianNB(input_matrix),)
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.01, XGBClassifier__max_depth=7, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.65)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                               -inf
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=5, XGBClassifier__min_child_weight=7, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.7)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           -1.10476
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.1, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=3, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.15)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           -1.15847
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (XGBClassifier(MinMaxScaler(input_matrix), XGB...
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=0.5, XGBClassifier__max_depth=9, XGBClassifier__min_child_weight=14, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.05)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           -1.51424
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   XGBClassifier(input_matrix, XGBClassifier__learning_rate=1.0, XGBClassifier__max_depth=5, XGBClassifier__min_child_weight=20, XGBClassifier__n_estimators=100, XGBClassifier__nthread=1, XGBClassifier__subsample=0.95)
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           -1.46565
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (XGBClassifier(StandardScaler(input_matrix), X...
#
# [6 rows x 192 columns]

# %%
print(tpot.score(X_test, y_test))
# Out:
# -1.10225800614

# %%
pd.DataFrame.from_dict(tpot.evaluated_individuals_)
# Out:
#                   BernoulliNB(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=False, ExtraTreesClassifier__criterion=gini, ExtraTreesClassifier__max_features=0.8, ExtraTreesClassifier__min_samples_leaf=2, ExtraTreesClassifier__min_samples_split=4, ExtraTreesClassifier__n_estimators=100), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.275336
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (LogisticRegression(ExtraTreesClassifier(input...
#
#                   BernoulliNB(LinearSVC(input_matrix, LinearSVC__C=15.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.0001), BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.397888
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   BernoulliNB(SelectFromModel(input_matrix, SelectFromModel__ExtraTreesClassifier__criterion=entropy, SelectFromModel__ExtraTreesClassifier__max_features=0.35, SelectFromModel__ExtraTreesClassifier__n_estimators=100, SelectFromModel__threshold=0.05), BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                               -inf
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                          0.0703118
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (LinearSVC(input_matrix, LinearSVC__C=15.0, Li...
#
#                   BernoulliNB(input_matrix, BernoulliNB__alpha=0.1, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.397888
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (BernoulliNB(LinearSVC(input_matrix, LinearSVC...
#
#                   BernoulliNB(input_matrix, BernoulliNB__alpha=10.0, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.497851
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (BernoulliNB(SelectFromModel(input_matrix, Sel...
#
#                   DecisionTreeClassifier(GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.1, GradientBoostingClassifier__max_depth=3, GradientBoostingClassifier__max_features=0.3, GradientBoostingClassifier__min_samples_leaf=16, GradientBoostingClassifier__min_samples_split=17, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.65), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=2, DecisionTreeClassifier__min_samples_split=14)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.599598
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (DecisionTreeClassifier(GradientBoostingClassi...
#
#                   DecisionTreeClassifier(GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.1, GradientBoostingClassifier__max_depth=3, GradientBoostingClassifier__max_features=0.3, GradientBoostingClassifier__min_samples_leaf=16, GradientBoostingClassifier__min_samples_split=6, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.65), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=2, DecisionTreeClassifier__min_samples_split=14)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.599598
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   DecisionTreeClassifier(SelectPercentile(input_matrix, SelectPercentile__percentile=29), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=5, DecisionTreeClassifier__min_samples_leaf=5, DecisionTreeClassifier__min_samples_split=18)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.530308
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (DecisionTreeClassifier(input_matrix, Decision...
#
#                   DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=2, DecisionTreeClassifier__min_samples_leaf=7, DecisionTreeClassifier__min_samples_split=11)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.522023
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                                                                                                                                                                  ...                                                                                                                                                  \
# crossover_count                                                                                                                                                  ...
# generation                                                                                                                                                       ...
# internal_cv_score                                                                                                                                                ...
# mutation_count                                                                                                                                                   ...
# operator_count                                                                                                                                                   ...
# predecessor                                                                                                                                                      ...
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=entropy, RandomForestClassifier__max_features=0.3, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=17, RandomForestClassifier__n_estimators=100)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.591418
# mutation_count                                                     2
# operator_count                                                     1
# predecessor        (RandomForestClassifier(input_matrix, RandomFo...
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.3, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=11, RandomForestClassifier__n_estimators=100)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.595388
# mutation_count                                                     3
# operator_count                                                     1
# predecessor        (RandomForestClassifier(input_matrix, RandomFo...
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.3, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=13, RandomForestClassifier__n_estimators=100)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.595388
# mutation_count                                                     2
# operator_count                                                     1
# predecessor        (RandomForestClassifier(input_matrix, RandomFo...
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.3, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=17, RandomForestClassifier__n_estimators=100)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.595388
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (RandomForestClassifier(input_matrix, RandomFo...
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.3, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.595388
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (RandomForestClassifier(input_matrix, RandomFo...
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.3, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=8, RandomForestClassifier__n_estimators=100)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.595388
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.8, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=17, RandomForestClassifier__n_estimators=100)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.579498
# mutation_count                                                     2
# operator_count                                                     1
# predecessor        (RandomForestClassifier(input_matrix, RandomFo...
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.95, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=8, RandomForestClassifier__n_estimators=100)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.540395
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (RandomForestClassifier(input_matrix, RandomFo...
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=1.0, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=8, RandomForestClassifier__n_estimators=100)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.522088
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (RandomForestClassifier(input_matrix, RandomFo...
#
#                   RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=True, RandomForestClassifier__criterion=gini, RandomForestClassifier__max_features=0.3, RandomForestClassifier__min_samples_leaf=20, RandomForestClassifier__min_samples_split=4, RandomForestClassifier__n_estimators=100)
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.587123
# mutation_count                                                     2
# operator_count                                                     1
# predecessor        (RandomForestClassifier(input_matrix, RandomFo...
#
# [6 rows x 100 columns]

# %%
pd.DataFrame.from_dict(tpot.evaluated_individuals_)
# Out:
#                   BernoulliNB(OneHotEncoder(input_matrix, OneHotEncoder__minimum_fraction=0.1, OneHotEncoder__sparse=False, OneHotEncoder__threshold=10), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=False)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.492854
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   BernoulliNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), BernoulliNB__alpha=1.0, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.421625
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   BernoulliNB(PolynomialFeatures(input_matrix, PolynomialFeatures__degree=2, PolynomialFeatures__include_bias=False, PolynomialFeatures__interaction_only=False), BernoulliNB__alpha=100.0, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.500776
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (BernoulliNB(PolynomialFeatures(input_matrix, ...
#
#                   BernoulliNB(VarianceThreshold(input_matrix, VarianceThreshold__threshold=0.001), BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.494339
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (BernoulliNB(input_matrix, BernoulliNB__alpha=...
#
#                   BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.518495
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   DecisionTreeClassifier(LinearSVC(input_matrix, LinearSVC__C=25.0, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=1e-05), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=4, DecisionTreeClassifier__min_samples_leaf=14, DecisionTreeClassifier__min_samples_split=18)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.552106
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   DecisionTreeClassifier(LinearSVC(input_matrix, LinearSVC__C=25.0, LinearSVC__dual=True, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=1e-05), DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=8, DecisionTreeClassifier__min_samples_leaf=14, DecisionTreeClassifier__min_samples_split=18)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.523355
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (DecisionTreeClassifier(LinearSVC(input_matrix...
#
#                   DecisionTreeClassifier(MaxAbsScaler(input_matrix), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=10, DecisionTreeClassifier__min_samples_leaf=6, DecisionTreeClassifier__min_samples_split=2)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.505392
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   DecisionTreeClassifier(Nystroem(input_matrix, Nystroem__gamma=0.0, Nystroem__kernel=laplacian, Nystroem__n_components=5), DecisionTreeClassifier__criterion=gini, DecisionTreeClassifier__max_depth=3, DecisionTreeClassifier__min_samples_leaf=11, DecisionTreeClassifier__min_samples_split=7)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.500776
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   DecisionTreeClassifier(input_matrix, DecisionTreeClassifier__criterion=entropy, DecisionTreeClassifier__max_depth=8, DecisionTreeClassifier__min_samples_leaf=3, DecisionTreeClassifier__min_samples_split=5)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.493656
# mutation_count                                                     1
# operator_count                                                     1
# predecessor                              (GaussianNB(input_matrix),)
#
#                                                                               ...                                                               \
# crossover_count                                                               ...
# generation                                                                    ...
# internal_cv_score                                                             ...
# mutation_count                                                                ...
# operator_count                                                                ...
# predecessor                                                                   ...
#
#                   GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=0.5, GradientBoostingClassifier__max_depth=10, GradientBoostingClassifier__max_features=0.45, GradientBoostingClassifier__min_samples_leaf=18, GradientBoostingClassifier__min_samples_split=16, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.95)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                           0.606209
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   GradientBoostingClassifier(input_matrix, GradientBoostingClassifier__learning_rate=1.0, GradientBoostingClassifier__max_depth=8, GradientBoostingClassifier__max_features=0.45, GradientBoostingClassifier__min_samples_leaf=12, GradientBoostingClassifier__min_samples_split=12, GradientBoostingClassifier__n_estimators=100, GradientBoostingClassifier__subsample=0.35)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                          0.0666809
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   LinearSVC(BernoulliNB(input_matrix, BernoulliNB__alpha=0.001, BernoulliNB__fit_prior=True), LinearSVC__C=15.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=1e-05)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.614441
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (LinearSVC(input_matrix, LinearSVC__C=15.0, Li...
#
#                   LinearSVC(BernoulliNB(input_matrix, BernoulliNB__alpha=0.01, BernoulliNB__fit_prior=True), LinearSVC__C=15.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=1e-05)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.614438
# mutation_count                                                     1
# operator_count                                                     2
# predecessor        (LinearSVC(input_matrix, LinearSVC__C=15.0, Li...
#
#                   LinearSVC(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.3, ExtraTreesClassifier__min_samples_leaf=13, ExtraTreesClassifier__min_samples_split=4, ExtraTreesClassifier__n_estimators=100), LinearSVC__C=10.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)  \
# crossover_count                                                    1
# generation                                                   INVALID
# internal_cv_score                                           0.555486
# mutation_count                                                     0
# operator_count                                                     2
# predecessor        (LinearSVC(ExtraTreesClassifier(input_matrix, ...
#
#                   LinearSVC(ExtraTreesClassifier(input_matrix, ExtraTreesClassifier__bootstrap=True, ExtraTreesClassifier__criterion=entropy, ExtraTreesClassifier__max_features=0.3, ExtraTreesClassifier__min_samples_leaf=5, ExtraTreesClassifier__min_samples_split=4, ExtraTreesClassifier__n_estimators=100), LinearSVC__C=10.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                             0.5567
# mutation_count                                                     0
# operator_count                                                     2
# predecessor                                                  (ROOT,)
#
#                   LinearSVC(input_matrix, LinearSVC__C=10.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l2, LinearSVC__tol=0.01)  \
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                             0.5564
# mutation_count                                                     1
# operator_count                                                     1
# predecessor        (LinearSVC(ExtraTreesClassifier(input_matrix, ...
#
#                   LinearSVC(input_matrix, LinearSVC__C=15.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=0.01)  \
# crossover_count                                                    1
# generation                                                   INVALID
# internal_cv_score                                           0.615668
# mutation_count                                                     0
# operator_count                                                     1
# predecessor        (LinearSVC(input_matrix, LinearSVC__C=15.0, Li...
#
#                   LinearSVC(input_matrix, LinearSVC__C=15.0, LinearSVC__dual=False, LinearSVC__loss=squared_hinge, LinearSVC__penalty=l1, LinearSVC__tol=1e-05)  \
# crossover_count                                                    0
# generation                                                         0
# internal_cv_score                                             0.6123
# mutation_count                                                     0
# operator_count                                                     1
# predecessor                                                  (ROOT,)
#
#                   LogisticRegression(input_matrix, LogisticRegression__C=10.0, LogisticRegression__dual=False, LogisticRegression__penalty=l2)
# crossover_count                                                    0
# generation                                                   INVALID
# internal_cv_score                                           0.585104
# mutation_count                                                     1
# operator_count                                                     1
# predecessor                              (GaussianNB(input_matrix),)
#
# [6 rows x 39 columns]

# %%
test_data = min_max_scaler.fit_transform(test_data_df)

# %% [markdown]
# # Appendix

# %% [markdown]
# ## K-nearest neighbors
#
# ### 5 neighbors
# Scale is the best, but still like 8.3 and 55%
#
# ```
# In [21]: %run classifiers.py --model "KNN"
# Cross validation logloss scores: -9.39785[0.22458]*
# Cross validation accuracy scores: 0.52094[0.00636]*
# Weighted AUC: 0.73311, Macro AUC: 0.66589
#
# In [2]: %run classifiers.py --model "KNN" --scale
# Cross validation logloss scores: -8.27549[0.53086]*
# Cross validation accuracy scores: 0.55144[0.00917]*
# Weighted and Macro AUC: 0.74460/0.68025
#
# In [22]: %run classifiers.py --model "KNN" --scale --drop
# Cross validation logloss scores: -8.27547[0.55342]*
# Cross validation accuracy scores: 0.55012[0.00737]*
# Weighted AUC: 0.74815, Macro AUC: 0.68535
# ```
#
# ### Increasing neighbors
# Increasing neighbors helps a lot with log-loss but not as much with accuracy, and still is a lot worse than the others:
#
# ```
# In [6]: %run classifiers.py --model "KNN" --scale --neighbors 10
# Cross validation logloss scores: -5.23405[0.42317]*
# Cross validation accuracy scores: 0.55537[0.01048]*
# Validation log-loss and accuracy: 5.10507 0.59358
# Weighted and Macro AUC: 0.78510/0.73661
#
# In [7]: %run classifiers.py --model "KNN" --scale --neighbors 20
# Cross validation logloss scores: -2.99511[0.29235]*
# Cross validation accuracy scores: 0.57171[0.00262]*
# Validation log-loss and accuracy: 2.98684 0.60122
# Weighted and Macro AUC: 0.80894/0.77096
#
# In [8]: %run classifiers.py --model "KNN" --scale --neighbors 50
# Cross validation logloss scores: -1.78031[0.08868]*
# Cross validation accuracy scores: 0.56352[0.00389]*
# Validation log-loss and accuracy: 1.76163 0.59969
# Weighted and Macro AUC: 0.82420/0.79622
#
# In [9]: %run classifiers.py --model "KNN" --scale --neighbors 100
# Cross validation logloss scores: -1.46001[0.05067]*
# Cross validation accuracy scores: 0.55436[0.00515]*
# Validation log-loss and accuracy: 1.45765 0.58976
# Weighted and Macro AUC: 0.82806/0.80784
#
# In [10]: %run classifiers.py --model "KNN" --scale --neighbors 200
# Cross validation logloss scores: -1.39694[0.02008]*
# Cross validation accuracy scores: 0.53209[0.00049]*
# Validation log-loss and accuracy: 1.33412 0.58060
# Weighted and Macro AUC: 0.82732/0.80952
# ```

# %% [markdown]
# ## Correlation matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt
mfcc_corr = np.corrcoef(train_data_df.iloc[:, 216:263].T)  # mfcc
mask = np.zeros_like(mfcc_corr)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(10, 10))
sns.heatmap(mfcc_corr, mask=mask, square=True)
plt.show()

# %%
chroma_corr = np.corrcoef(train_data_df.iloc[:, 168:216].T)  # chroma
plt.figure(figsize=(15, 15))
sns.heatmap(chroma_corr, square=True)
plt.show()
